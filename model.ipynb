# %%
# Importing important packages
import os
import sys

# Data Wrangling and manipulation
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from sklearn.model_selection import train_test_split

import nltk
from nltk.tokenize import word_tokenize

# %%
df = pd.read_csv('cleaned_Resume.csv')
# Out:
#                                                  resume      role  role_id
# 0     hr administrator marketing associate hr admini...        HR       19
# 1     hr specialist hr operation summary versatile m...        HR       19
# 2     hr director summary year experience recruiting...        HR       19
# 3     hr specialist summary dedicate driven dynamic ...        HR       19
# 4     hr manager skill highlight hr skill hr departm...        HR       19
# ...                                                 ...       ...      ...
# 2476  advanced level wheel vehicle mechanic career f...  AVIATION        6
# 2477  rank sgt e non commission officer charge briga...  AVIATION        6
# 2478  government relation communication organization...  AVIATION        6
# 2479  geek squad agent professional profile support ...  AVIATION        6
# 2480  program director office manager summary highly...  AVIATION        6
#
# [2481 rows x 3 columns]

# %% [markdown]
# # Exploratory Data Analysis : check word frequency

# %%
all_records = ''

# combining records into one string
for record in df['resume']:
    all_records += record

# %%
all_tokens = word_tokenize(all_records) # tokenize word in list
word_freq = nltk.FreqDist(all_tokens)
mostcommon = word_freq.most_common(30)
common = pd.DataFrame(mostcommon)
common.rename(columns={0:'word', 1:'frequency'}, inplace = True)

# %%
plt.xticks(rotation=90)
plt.title('Most common words')
sns.barplot(common, x='word', y='frequency')
# Out:
# <AxesSubplot: title={'center': 'Most common words'}, xlabel='word', ylabel='frequency'>

# %% [markdown]
# # feature extraction : BoW, TF-IDF

# %%
# Creating the Bag of Words model
word2count = {}
for resume in df['resume']:
    words = nltk.word_tokenize(resume)
    for word in words:
        if word not in word2count.keys():
            word2count[word] = 1
        else:
            word2count[word] += 1

# %%
word2count
# Out:
# {'hr': 1470,
#  'administrator': 575,
#  'marketing': 4313,
#  'associate': 1974,
#  'summary': 2053,
#  'dedicated': 207,
#  'customer': 11340,
#  'service': 9067,
#  'manager': 5554,
#  'year': 3695,
#  'experience': 6251,
#  'hospitality': 165,
#  'management': 12176,
#  'respect': 115,
#  'builder': 121,
#  'leader': 1038,
#  'focus': 1289,
#  'team': 7145,
#  'strive': 45,
#  'instill': 17,
#  'share': 386,
#  'enthusiastic': 188,
#  'commitment': 156,
#  'highlight': 1123,
#  'satisfaction': 967,
#  'savvy': 112,
#  'conflict': 388,
#  'resolution': 774,
#  'technique': 820,
#  'training': 5262,
#  'development': 5810,
#  'skilled': 518,
#  'multi': 945,
#  'tasker': 110,
#  'client': 6492,
#  'relation': 2036,
#  'specialist': 1368,
#  'accomplishment': 1208,
#  'missouri': 54,
#  'dot': 50,
#  'supervisor': 1102,
#  'certification': 1057,
#  'certify': 1216,
#  'ihg': 6,
#  'loyalty': 146,
#  'segment': 129,
#  'hilton': 21,
#  'worldwide': 85,
#  'general': 1858,
#  'accomplish': 286,
#  'trainer': 411,
#  'cross': 706,
#  'server': 1482,
#  'system': 7097,
#  'onq': 3,
#  'micros': 1,
#  'opera': 11,
#  'pms': 14,
#  'fidelio': 1,
#  'reservation': 105,
#  'holidex': 1,
#  'complete': 2094,
#  'course': 1100,
#  'seminar': 308,
#  'sale': 8513,
#  'strategy': 2409,
#  'inventory': 2367,
#  'control': 2584,
#  'loss': 403,
#  'prevention': 217,
#  'safety': 2009,
#  'time': 2935,
#  'leadership': 2401,
#  'performance': 2561,
#  'assessment': 787,
#  'dec': 232,
#  'current': 2788,
#  'company': 15715,
#  'name': 11777,
#  'city': 15107,
#  'state': 16294,
#  'help': 1747,
#  'develop': 5947,
#  'policy': 2586,
#  'direct': 1769,
#  'coordinate': 2093,
#  'activity': 2502,
#  'employment': 470,
#  'compensation': 407,
#  'labor': 435,
#  'benefit': 1137,
#  'employee': 4389,
#  'prepare': 3072,
#  'separation': 37,
#  'notice': 92,
#  'relate': 1243,
#  'documentation': 1463,
#  'keep': 1035,
#  'record': 2714,
#  'plan': 4403,
#  'participation': 169,
#  'insurance': 1088,
#  'pension': 36,
#  'personnel': 1607,
#  'transaction': 836,
#  'hire': 1398,
#  'promotion': 724,
#  'transfer': 443,
#  'review': 2634,
#  'termination': 170,
#  'statistic': 217,
#  'government': 723,
#  'reporting': 929,
#  'advise': 325,
#  'appropriate': 1213,
#  'issue': 2720,
#  'administer': 544,
#  'program': 5063,
#  'life': 620,
#  'health': 2043,
#  'dental': 164,
#  'vacation': 65,
#  'sick': 37,
#  'leave': 273,
#  'absence': 124,
#  'assistance': 664,
#  'design': 5018,
#  'create': 3961,
#  'collateral': 211,
#  'meeting': 1974,
#  'trade': 442,
#  'show': 536,
#  'executive': 1823,
#  'manage': 6615,
#  'house': 492,
#  'advertising': 729,
#  'consist': 196,
#  'print': 547,
#  'medium': 2269,
#  'piece': 105,
#  'assist': 3630,
#  'launch': 540,
#  'website': 885,
#  'month': 1307,
#  'official': 167,
#  'page': 352,
#  'facebook': 156,
#  'facilitate': 751,
#  'interaction': 259,
#  'analyze': 1586,
#  'rating': 126,
#  'programming': 473,
#  'feature': 425,
#  'competitor': 117,
#  'evaluate': 920,
#  'effectiveness': 253,
#  'advanced': 561,
#  'medical': 1521,
#  'claim': 689,
#  'analyst': 854,
#  'mar': 203,
#  'bill': 407,
#  'accuracy': 724,
#  'treatment': 439,
#  'test': 1616,
#  'hospital': 574,
#  'stay': 178,
#  'prior': 277,
#  'sanction': 12,
#  'train': 2009,
#  'interpret': 265,
#  'code': 868,
#  'icd': 95,
#  'cpt': 71,
#  'terminology': 114,
#  'commonly': 6,
#  'use': 4430,
#  'billing': 916,
#  'fully': 102,
#  'understand': 461,
#  'paperwork': 267,
#  'submit': 396,
#  'healthcare': 820,
#  'provider': 490,
#  'require': 1174,
#  'organizational': 1222,
#  'analytical': 551,
#  'skill': 8091,
#  'well': 2622,
#  'computer': 1896,
#  'knowledge': 2130,
#  'procedure': 2768,
#  'standard': 1872,
#  'datum': 2758,
#  'analysis': 3136,
#  'law': 807,
#  'regard': 1057,
#  'assistant': 1707,
#  'jun': 247,
#  'perform': 2746,
#  'duty': 1249,
#  'include': 6117,
#  'limit': 335,
#  'budgeting': 401,
#  'financial': 4339,
#  'account': 4996,
#  'human': 1550,
#  'resource': 2229,
#  'payroll': 1498,
#  'purchasing': 327,
#  'establish': 1572,
#  'maintain': 5962,
#  'close': 731,
#  'work': 8694,
#  'relationship': 2141,
#  'department': 2857,
#  'hotel': 308,
#  'ensure': 3933,
#  'maximum': 97,
#  'operation': 3700,
#  'productivity': 554,
#  'morale': 76,
#  'guest': 720,
#  'handle': 1279,
#  'daily': 2388,
#  'report': 5205,
#  'directly': 398,
#  'corporate': 1289,
#  'office': 4425,
#  'staff': 4210,
#  'overall': 591,
#  'objective': 861,
#  'goal': 2160,
#  'emphasis': 151,
#  'high': 3384,
#  'public': 1860,
#  'local': 1000,
#  'business': 8087,
#  'chamber': 132,
#  'commerce': 257,
#  'support': 5073,
#  'jul': 156,
#  'provide': 5650,
#  'various': 1995,
#  'head': 394,
#  'front': 409,
#  'end': 1345,
#  'friendly': 387,
#  'efficient': 544,
#  'swift': 27,
#  'preserve': 45,
#  'comply': 181,
#  'exemplify': 12,
#  'second': 148,
#  'none': 9,
#  'delivery': 1180,
#  'potential': 644,
#  'owner': 532,
#  'partner': 961,
#  'may': 1439,
#  'price': 401,
#  'integrity': 260,
#  'coordinator': 853,
#  'aug': 248,
#  'education': 4098,
#  'n': 175,
#  'administration': 1997,
#  'jefferson': 13,
#  'college': 1865,
#  'advertise': 98,
#  'school': 2745,
#  'diploma': 581,
#  'prep': 157,
#  'study': 939,
#  'sainte': 1,
#  'genevieve': 2,
#  'senior': 1596,
#  'award': 1574,
#  'american': 513,
#  'shrubel': 1,
#  'scholarship': 238,
#  'accounting': 2469,
#  'ad': 514,
#  'layout': 311,
#  'poster': 60,
#  'presentation': 1393,
#  'versatile': 71,
#  'professional': 4188,
#  'background': 646,
#  'communication': 3655,
#  'market': 1913,
#  'technology': 2424,
#  'group': 1694,
#  'change': 1767,
#  'outage': 29,
#  'job': 1388,
#  'aid': 550,
#  'comprehensive': 377,
#  'new': 6423,
#  'contractor': 559,
#  'audit': 812,
#  'posting': 98,
#  'old': 154,
#  'pending': 3,
#  'hold': 317,
#  'draft': 372,
#  'position': 1250,
#  'union': 198,
#  'hourly': 82,
#  'non': 652,
#  'salary': 222,
#  'check': 1152,
#  'drug': 208,
#  'screen': 278,
#  'conduct': 1930,
#  'monthly': 1914,
#  'brief': 99,
#  'across': 689,
#  'unit': 1058,
#  'serve': 1567,
#  'link': 125,
#  'vendor': 1566,
#  'question': 676,
#  'resolve': 1541,
#  'real': 536,
#  'process': 6074,
#  'improvement': 1345,
#  'feedback': 443,
#  'key': 1410,
#  'metric': 391,
#  'initiative': 888,
#  'successfully': 822,
#  'brand': 1060,
#  'sharepoint': 254,
#  'site': 1499,
#  'project': 7951,
#  'rfi': 47,
#  'rfp': 102,
#  'co': 555,
#  'op': 76,
#  'post': 663,
#  'article': 221,
#  'update': 1237,
#  'graphic': 628,
#  'visual': 514,
#  'research': 2502,
#  'story': 226,
#  'promote': 1113,
#  'edit': 351,
#  'content': 1024,
#  'quarterly': 562,
#  'publish': 141,
#  'newsletter': 273,
#  'internal': 1366,
#  'external': 755,
#  'event': 2452,
#  'collaborate': 841,
#  'determine': 1003,
#  'need': 3710,
#  'material': 2509,
#  'web': 1095,
#  'digital': 897,
#  'entrust': 19,
#  'lead': 3279,
#  'product': 4856,
#  'software': 2657,
#  'asset': 711,
#  'tool': 1329,
#  'toolkit': 5,
#  'tradeshow': 46,
#  'calendar': 239,
#  'approval': 331,
#  'alignment': 102,
#  'guideline': 592,
#  'branding': 45,
#  'mysikorsky': 1,
#  'timely': 978,
#  'solution': 1540,
#  'mitigate': 72,
#  'board': 844,
#  'produce': 746,
#  'video': 590,
#  'annual': 1282,
#  'hand': 565,
#  'meet': 1937,
#  'pre': 464,
#  'campaign': 932,
#  'generate': 814,
#  'order': 2682,
#  'advisor': 264,
#  'improve': 1593,
#  'modify': 183,
#  'increase': 2135,
#  'awareness': 425,
#  'promotional': 336,
#  'publication': 325,
#  'supervised': 163,
#  'distribution': 448,
#  'quality': 3393,
#  'output': 98,
#  'brochure': 179,
#  'designer': 823,
#  'tracking': 385,
#  'appointment': 446,
#  'teller': 181,
#  'receive': 1374,
#  'score': 200,
#  'audits': 482,
#  'atm': 68,
#  'machine': 533,
#  'educate': 327,
#  'variety': 543,
#  'retail': 972,
#  'available': 313,
#  'credit': 1355,
#  'option': 202,
#  'consistently': 606,
#  'exceed': 672,
#  'identity': 70,
#  'implement': 3000,
#  'achieve': 1245,
#  'organize': 1672,
#  'sponsor': 166,
#  'campus': 327,
#  'result': 2071,
#  'coach': 946,
#  'peer': 204,
#  'proper': 890,
#  'flow': 694,
#  'efficiency': 738,
#  'utilize': 1028,
#  'sell': 811,
#  'refer': 137,
#  'base': 2264,
#  'individual': 1028,
#  'grand': 72,
#  'opening': 247,
#  'branch': 546,
#  'location': 642,
#  'strengthen': 123,
#  'affinity': 10,
#  'producer': 160,
#  'shu': 2,
#  'exchange': 421,
#  'execute': 980,
#  'connecticut': 33,
#  'creative': 929,
#  'corridor': 13,
#  'growth': 846,
#  'industry': 1010,
#  'opportunity': 1139,
#  'come': 181,
#  'panel': 123,
#  'address': 626,
#  'topic': 133,
#  'host': 194,
#  'answer': 880,
#  'session': 379,
#  'approximately': 172,
#  'attendee': 54,
#  'follow': 1378,
#  'forum': 61,
#  'invite': 61,
#  'engage': 428,
#  'networking': 236,
#  'conversation': 57,
#  'reception': 129,
#  'master': 995,
#  'art': 2055,
#  'sacred': 3,
#  'heart': 81,
#  'university': 3513,
#  'bachelor': 1579,
#  'relational': 39,
#  'western': 100,
#  'adobe': 577,
#  'photoshop': 336,
#  'adp': 206,
#  'care': 1746,
#  'final': 285,
#  'cut': 220,
#  'pro': 240,
#  'illustrator': 224,
#  'indesign': 128,
#  'innovation': 159,
#  'lotus': 124,
#  'note': 303,
#  'microsoft': 2828,
#  'recruitment': 656,
#  'director': 1869,
#  'recruiting': 328,
#  'plus': 177,
#  'hris': 168,
#  'maintenance': 1824,
#  'enviroment': 2,
#  'recruit': 625,
#  'fmla': 80,
#  'eeo': 41,
#  'flsa': 20,
#  'kansas': 41,
#  'institute': 519,
#  'outcome': 214,
#  'memberships': 13,
#  'accolade': 12,
#  'member': 3070,
#  'shrm': 53,
#  'friend': 53,
#  'president': 640,
#  'honor': 489,
#  'roll': 170,
#  'dean': 246,
#  'student': 3506,
#  'liaison': 591,
#  'topeka': 7,
#  'mother': 33,
#  'federation': 31,
#  'several': 533,
#  'production': 1969,
#  'nominate': 42,
#  'addy': 2,
#  'recognition': 287,
#  'outstanding': 482,
#  'travel': 715,
#  'tourism': 80,
#  'ashhra': 1,
#  'kahhr': 1,
#  'acm': 1,
#  'additional': 960,
#  'information': 4504,
#  'instrumental': 78,
#  'implementation': 1430,
#  'adjutant': 8,
#  'retention': 417,
#  'involve': 621,
#  'survey': 419,
#  'present': 1164,
#  'retain': 162,
#  'qualified': 213,
#  'talent': 341,
#  'task': 1364,
#  'federal': 661,
#  'security': 1474,
#  'joint': 137,
#  'force': 360,
#  'headquarters': 65,
#  'clearance': 161,
#  'per': 920,
#  'requirement': 1735,
#  'lmis': 1,
#  'vacancy': 51,
#  'able': 575,
#  'less': 146,
#  'man': 136,
#  'hour': 745,
#  'inexperienced': 2,
#  'jvc': 1,
#  'responsible': 2717,
#  'database': 2010,
#  'last': 135,
#  'three': 434,
#  'cultivate': 184,
#  'renew': 36,
#  'contact': 885,
#  'active': 596,
#  'fte': 30,
#  'usage': 138,
#  'budget': 3080,
#  'turnover': 109,
#  'field': 1068,
#  'take': 1100,
#  'respond': 559,
#  'request': 1292,
#  'facility': 1198,
#  'along': 283,
#  'reduce': 823,
#  'contract': 1701,
#  'cost': 2179,
#  'nursing': 455,
#  'unique': 231,
#  'pay': 437,
#  'structure': 420,
#  'prn': 3,
#  'utilization': 141,
#  'continually': 100,
#  'think': 109,
#  'outside': 345,
#  'box': 200,
#  'face': 191,
#  'environment': 1717,
#  'firm': 322,
#  'agency': 1055,
#  'processing': 834,
#  'oversee': 845,
#  'role': 650,
#  'clinician': 18,
#  'physician': 411,
#  'author': 156,
#  'handbook': 86,
#  'coaching': 213,
#  'depth': 162,
#  'legal': 651,
#  'day': 1599,
#  'risk': 901,
#  'regulatory': 396,
#  'compliance': 1631,
#  'recommend': 519,
#  'oversaw': 275,
#  'develpe': 1,
#  'supervisory': 149,
#  'shro': 2,
#  'automation': 328,
#  'statewide': 47,
#  'classified': 42,
#  'unclassified': 9,
#  'routine': 225,
#  'arise': 84,
#  'document': 1841,
#  'approve': 359,
#  'disapprove': 3,
#  'wage': 97,
#  'minimum': 86,
#  'rate': 572,
#  'significant': 156,
#  'description': 179,
#  'determined': 52,
#  'reclassification': 5,
#  'pursue': 119,
#  'range': 474,
#  'comparable': 6,
#  'classify': 45,
#  'exist': 730,
#  'consult': 291,
#  'tag': 82,
#  'military': 383,
#  'technical': 2255,
#  'common': 157,
#  'sense': 82,
#  'guidance': 320,
#  'properly': 314,
#  'sensitive': 129,
#  'complex': 733,
#  'ever': 70,
#  'innovative': 394,
#  'idea': 296,
#  'staffing': 420,
#  'representative': 1035,
#  'negotiation': 544,
#  'kape': 1,
#  'th': 315,
#  'fire': 259,
#  'sr': 198,
#  'recruiter': 130,
#  'ramp': 28,
#  'hiring': 170,
#  'agent': 419,
#  'placement': 270,
#  'cover': 242,
#  'set': 1454,
#  'coordinated': 148,
#  'facilitated': 177,
#  'manpower': 63,
#  'planning': 2108,
#  'career': 704,
#  'statutory': 66,
#  'regulation': 811,
#  'person': 548,
#  'mid': 102,
#  'level': 2355,
#  'ground': 200,
#  'monitor': 1785,
#  'source': 568,
#  'appraisal': 137,
#  'corrective': 161,
#  'action': 757,
#  'one': 1049,
#  'osha': 208,
#  'comp': 28,
#  'etc': 817,
#  'degree': 565,
#  'united': 598,
#  'states': 496,
#  'earn': 240,
#  'semester': 126,
#  'science': 2103,
#  'honors': 64,
#  'ambassador': 62,
#  'association': 719,
#  'legislative': 33,
#  'desktop': 316,
#  'worker': 691,
#  'pagemaker': 10,
#  'back': 383,
#  'corel': 18,
#  'suite': 657,
#  'harvard': 16,
#  'access': 1101,
#  'excel': 2003,
#  'publisher': 168,
#  'ms': 1242,
#  'word': 1352,
#  'quark': 16,
#  'express': 106,
#  'quattro': 3,
#  'strategic': 1721,
#  'wordperfect': 16,
#  'dedicate': 175,
#  'driven': 7,
#  'dynamic': 349,
#  'expertise': 742,
#  'motivate': 656,
#  'contribute': 459,
#  'success': 609,
#  'solid': 238,
#  'player': 617,
#  'prove': 441,
#  'ability': 1594,
#  'rapport': 174,
#  'type': 594,
#  'wpm': 82,
#  'touch': 75,
#  'programs': 21,
#  'outlook': 717,
#  'powerpoint': 826,
#  'telephone': 723,
#  'inquiry': 604,
#  'excellent': 1523,
#  'call': 1980,
#  'primary': 355,
#  'inbound': 168,
#  'outbound': 163,
#  'center': 1582,
#  'oral': 225,
#  'write': 1783,
#  'season': 152,
#  'oct': 210,
#  'accenture': 18,
#  'peopleline': 1,
#  'email': 693,
#  'initial': 212,
#  'point': 866,
#  'practice': 1141,
#  'route': 233,
#  'caseworker': 6,
#  'track': 1279,
#  'via': 486,
#  'case': 856,
#  'initiation': 33,
#  'detail': 1124,
#  'complaint': 601,
#  'comment': 68,
#  'feb': 160,
#  'filing': 422,
#  'method': 751,
#  'short': 239,
#  'term': 676,
#  'disability': 159,
#  'respective': 48,
#  'global': 672,
#  'clientele': 146,
#  'departmental': 320,
#  'people': 664,
#  'communicate': 1052,
#  'query': 175,
#  'centre': 30,
#  'shift': 427,
#  'dispatch': 109,
#  'san': 311,
#  'antonio': 28,
#  'surround': 59,
#  'area': 2027,
#  'monitoring': 407,
#  'adhere': 278,
#  'book': 457,
#  'correct': 524,
#  'weekend': 63,
#  'certificate': 709,
#  'completion': 575,
#  'texas': 305,
#  'extension': 103,
#  'startup': 82,
#  'organization': 1841,
#  'startups': 1,
#  'ada': 83,
#  'wc': 13,
#  'mediation': 80,
#  'advocacy': 80,
#  'benefits': 96,
#  'unemployment': 65,
#  'orientation': 382,
#  'boarding': 140,
#  'technologies': 32,
#  'applications': 7,
#  'lawson': 39,
#  'paychex': 19,
#  'kronos': 45,
#  'visio': 171,
#  'jan': 652,
#  'function': 1028,
#  'e': 1020,
#  'cycle': 397,
#  'fulfillment': 84,
#  'foster': 281,
#  'orient': 1103,
#  'culture': 226,
#  'emphasize': 49,
#  'continuous': 236,
#  'conformation': 2,
#  'applicable': 184,
#  'statute': 19,
#  'identify': 1697,
#  'concern': 547,
#  'effective': 1218,
#  'creation': 439,
#  'insure': 155,
#  'regional': 502,
#  'feel': 78,
#  'like': 286,
#  'part': 850,
#  'essential': 105,
#  'top': 769,
#  'nationally': 46,
#  'vision': 265,
#  'vstd': 1,
#  'vltd': 1,
#  'k': 597,
#  'successful': 761,
#  'expect': 127,
#  'first': 1086,
#  'within': 1703,
#  'align': 212,
#  'start': 426,
#  'effort': 633,
#  'full': 590,
#  'convert': 84,
#  'file': 1401,
#  'direction': 526,
#  'continue': 334,
#  'grow': 491,
#  'peak': 69,
#  'temporary': 115,
#  'volume': 537,
#  'total': 466,
#  'deliver': 955,
#  'million': 965,
#  'black': 99,
#  'friday': 14,
#  'christmas': 25,
#  'influence': 150,
#  'tactical': 109,
#  'consistency': 105,
#  'multiple': 1338,
#  'interact': 386,
#  'exempt': 64,
#  'functional': 769,
#  'trend': 659,
#  'accurate': 884,
#  'throughout': 588,
#  'demonstrate': 662,
#  'fanatic': 1,
#  'core': 720,
#  'value': 600,
#  'workforce': 168,
#  'line': 1316,
#  'police': 141,
#  'good': 1446,
#  'deal': 298,
#  'poor': 20,
#  'attendance': 262,
#  'behavior': 445,
#  'champion': 73,
#  'fun': 66,
#  'approachable': 21,
#  'confidentiality': 144,
#  'accordance': 467,
#  'expectation': 401,
#  'look': 280,
#  'way': 344,
#  'innovate': 23,
#  'measurable': 27,
#  'bottom': 78,
#  'impact': 344,
#  'solely': 29,
#  'situation': 329,
#  'compliant': 66,
#  'separate': 79,
#  'community': 1856,
#  'profit': 734,
#  'play': 296,
#  'merge': 24,
#  'five': 277,
#  'private': 377,
#  'package': 488,
#  'incentive': 145,
#  'teamwork': 148,
#  'open': 700,
#  'door': 94,
#  'conducive': 37,
#  'positive': 845,
#  'dialogue': 22,
#  'negotiate': 620,
#  'offer': 696,
#  'nonexempt': 5,
#  'physicians': 7,
#  'ceo': 168,
#  'coo': 20,
#  'cfo': 81,
#  'cmo': 3,
#  'manual': 405,
#  'disciplinary': 136,
#  'introduce': 240,
#  'formal': 83,
#  'category': 171,
#  'shadow': 40,
#  'interview': 885,
#  'construct': 105,
#  'picture': 72,
#  'nation': 70,
#  'large': 814,
#  'small': 499,
#  'discount': 73,
#  'retailer': 54,
#  'fulfil': 67,
#  'broad': 133,
#  'generalist': 124,
#  'workshop': 348,
#  'sound': 252,
#  'decision': 674,
#  'sq': 28,
#  'ft': 55,
#  'boost': 148,
#  'special': 1378,
#  'picnic': 5,
#  'banquet': 168,
#  'investigate': 296,
#  'sexual': 65,
#  'harassment': 34,
#  'discrimination': 14,
#  'inappropriate': 6,
#  'either': 49,
#  'among': 204,
#  'mount': 76,
#  'vernon': 3,
#  'nazarene': 7,
#  'affiliation': 394,
#  'society': 488,
#  'muskingum': 2,
#  'valley': 96,
#  'make': 2027,
#  'win': 313,
#  'problem': 2344,
#  'solve': 964,
#  'quantitative': 90,
#  'administrative': 1406,
#  'prioritize': 241,
#  'simultaneously': 159,
#  'seek': 436,
#  'responsibility': 1220,
#  'authority': 172,
#  'proficiency': 402,
#  'spreadsheet': 531,
#  'meticulous': 83,
#  'attention': 416,
#  'self': 828,
#  'mature': 52,
#  'starter': 145,
#  'visa': 77,
#  'immigrant': 13,
#  'faculty': 255,
#  'enhance': 518,
#  'operational': 780,
#  'authorization': 123,
#  'percent': 60,
#  'petition': 10,
#  'uscis': 7,
#  'adjudication': 16,
#  'electronic': 720,
#  'mandate': 48,
#  'usdhs': 1,
#  'usdo': 1,
#  'edited': 2,
#  'internally': 39,
#  'distribute': 396,
#  'bi': 226,
#  'advice': 115,
#  'scholar': 83,
#  'thoroughly': 62,
#  'highly': 716,
#  'confidential': 176,
#  'designate': 107,
#  'alternate': 42,
#  'officer': 682,
#  'j': 149,
#  'visitor': 191,
#  'foreign': 210,
#  'national': 1129,
#  'obtain': 678,
#  'h': 202,
#  'b': 803,
#  'status': 677,
#  'u': 336,
#  ...}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

texts = data

tfidf = TfidfVectorizer(min_df = 2, max_df = 0.5, ngram_range = (1, 2))
features = tfidf.fit_transform(texts)
 
pd.Dataframe(features.todense(), columns = tfidf.get_feature_names())
# Out:
#   Cell In [23], line 3
#
#     texts = data/
#
#                  ^
#
# SyntaxError: invalid syntax

# %%
def hello():
    a=1
    b=2
    return [a, b]

hello()
# Out:
# [1, 2]
